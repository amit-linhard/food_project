# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import math

# %%
df_parsed = pd.read_csv('input/df_parsed.csv')
df_recipes = pd.read_csv('input/df_recipes.csv')

# %%
df_recipes.head()
# Out:
#                                          recipe_urls  \
# 0  https://www.jamieoliver.com/recipes/duck-recip...
# 1  https://www.jamieoliver.com/recipes/vegetable-...
# 2  https://www.jamieoliver.com/recipes/pasta-reci...
# 3  https://www.jamieoliver.com/recipes/vegetable-...
# 4  https://www.jamieoliver.com/recipes/chicken-re...
#
#                      recipe_name  \
# 0  Roast duck with Marsala gravy
# 1     Best-ever Brussels sprouts
# 2  Beautiful courgette carbonara
# 3     Roasted black bean burgers
# 4     Chicken & tofu noodle soup
#
#                                          ingredients
# 0  ['1 x 1.6kg whole duck', '2 heaped teaspoons C...
# 1  ['800 g Brussels sprouts', '2 higher-welfare C...
# 2  ['6 medium green and yellow courgettes', '500 ...
# 3  ['1½ red onions', '200 g mixed mushrooms', '10...
# 4  ['2 shallots', '2 cloves of garlic', '2 cm pie...

# %%
# Define features
cuisines = ["Chinese", "Italian", "Mexican", "French", "Indian", "Japanese", "Thai",  "American"]
cooking_level = ["Easy", "Medium", "Hard"]
cooking_time = [15, 30, 45, 60, 75, 90, 105, 120]
general_rank = [1, 2, 3, 4, 5]
# disliked = -1, didn't rank = 0, liked = 1:
like = [-1, 0, 1]
user_rank = [1, 2, 3, 4, 5]
cols = [cuisines, cooking_level, cooking_time, general_rank, like, user_rank]
cols_names = ["cuisines", "cooking_level", "cooking_time", "general_rank", "like", "user_rank"]

# %% [markdown]
# ### Functions declerations

# %%
def add_cols_to_df(df, cols):
    """
    Add columns to a dataframe
    """
    for col in cols:
        df[col] = None
    return df

# generates an arbitary array of values for each feature we are adding to DF
def generate_random_instances(feature, number):
    instances = []
    for i in range(number):
        instances.append(random.choice(feature))
    return instances

## find dist of each category under each new feature:
def show_dist_of_cols(df, cols_names):
    for col in cols_names:
        distribution = df[col].value_counts(normalize=True,sort=True)
        print(f'{col}: {distribution}')
        
def weight_recipe(rating):
    return math.log(rating)

# %% [markdown]
# ### ------------------------------------

# %%
# df_parsed = add_cols_to_df(df_parsed, cols_names)
# df_recipes = add_cols_to_df(df_recipes, cols_names)

# %%
print(f'df_recipes shape: {df_recipes.shape}')
print(f'df_parsed shape: {df_parsed.shape}')
# Out:
# df_recipes shape: (4647, 3)
# df_parsed shape: (4647, 4)

# %%
# creating df of the new generated features:
number = df_parsed.shape[0]
cuisines_data = generate_random_instances(cuisines, number)
cooking_time_data = generate_random_instances(cooking_time, number)
cooking_level_data = generate_random_instances(cooking_level, number)
general_rank_data = generate_random_instances(general_rank, number)
like_data = generate_random_instances(like, number)
user_rank_data = generate_random_instances(user_rank, number)
data = {'cuisines': cuisines_data, 'cooking_time': cooking_time_data, 'cooking_level': cooking_level_data, 'general_rank': general_rank_data, 'like': like_data, 'user_rank': user_rank_data}
new_features_df = pd.DataFrame(data)

# %%
show_dist_of_cols(new_features_df, cols_names)
# Out:
# cuisines: Chinese     0.132774
# Japanese    0.129976
# Italian     0.128900
# Indian      0.128685
# Thai        0.122445
# French      0.119862
# Mexican     0.119217
# American    0.118141
# Name: cuisines, dtype: float64
# cooking_level: Hard      0.347966
# Easy      0.329675
# Medium    0.322359
# Name: cooking_level, dtype: float64
# cooking_time: 105    0.131052
# 120    0.126964
# 60     0.125027
# 30     0.124597
# 45     0.124166
# 90     0.123521
# 75     0.122875
# 15     0.121799
# Name: cooking_time, dtype: float64
# general_rank: 4    0.209167
# 1    0.206155
# 3    0.198408
# 2    0.193458
# 5    0.192813
# Name: general_rank, dtype: float64
# like:  1    0.334194
# -1    0.333764
#  0    0.332042
# Name: like, dtype: float64
# user_rank: 4    0.202496
# 1    0.201635
# 5    0.200775
# 3    0.199699
# 2    0.195395
# Name: user_rank, dtype: float64

# %%
df_recipes = pd.concat([df_recipes, new_features_df],axis=1)
df_parsed = pd.concat([df_parsed, new_features_df],axis=1)

# %%
df_recipes.columns
# Out:
# Index(['recipe_urls', 'recipe_name', 'ingredients', 'cuisines', 'cooking_time',
#        'cooking_level', 'general_rank', 'like', 'user_rank'],
#       dtype='object')

# %%
df_parsed.columns
# Out:
# Index(['recipe_urls', 'recipe_name', 'ingredients', 'ingredients_parsed',
#        'cuisines', 'cooking_time', 'cooking_level', 'general_rank', 'like',
#        'user_rank'],
#       dtype='object')

# %%
df_recipes.head()
# Out:
#                                          recipe_urls  \
# 0  https://www.jamieoliver.com/recipes/duck-recip...
# 1  https://www.jamieoliver.com/recipes/vegetable-...
# 2  https://www.jamieoliver.com/recipes/pasta-reci...
# 3  https://www.jamieoliver.com/recipes/vegetable-...
# 4  https://www.jamieoliver.com/recipes/chicken-re...
#
#                      recipe_name  \
# 0  Roast duck with Marsala gravy
# 1     Best-ever Brussels sprouts
# 2  Beautiful courgette carbonara
# 3     Roasted black bean burgers
# 4     Chicken & tofu noodle soup
#
#                                          ingredients  cuisines  cooking_time  \
# 0  ['1 x 1.6kg whole duck', '2 heaped teaspoons C...  American           105
# 1  ['800 g Brussels sprouts', '2 higher-welfare C...    French           120
# 2  ['6 medium green and yellow courgettes', '500 ...    Indian            15
# 3  ['1½ red onions', '200 g mixed mushrooms', '10...    French            60
# 4  ['2 shallots', '2 cloves of garlic', '2 cm pie...  Japanese           120
#
#   cooking_level  general_rank  like  user_rank
# 0          Easy             5     1          2
# 1          Hard             4    -1          4
# 2          Hard             4     1          5
# 3          Hard             3    -1          4
# 4          Easy             4    -1          4

# %%
# df_recipes.to_csv('input/df_recipes_augmanted.csv')
# df_parsed.to_csv('input/df_parsed_augmanted.csv')

# %%
for df in [df_recipes, df_parsed]:
    for col in ['general_rank', 'user_rank']:
        col_name = col + "_weighted"
        df[col_name] = df[col].apply(weight_recipe)

# %%
df_recipes
# Out:
#                                             recipe_urls  \
# 0     https://www.jamieoliver.com/recipes/duck-recip...
# 1     https://www.jamieoliver.com/recipes/vegetable-...
# 2     https://www.jamieoliver.com/recipes/pasta-reci...
# 3     https://www.jamieoliver.com/recipes/vegetable-...
# 4     https://www.jamieoliver.com/recipes/chicken-re...
# ...                                                 ...
# 4642  https://www.allrecipes.com/recipe/213809/thai-...
# 4643  https://www.allrecipes.com/recipe/41751/delici...
# 4644  https://www.allrecipes.com/recipe/264507/spicy...
# 4645  https://www.allrecipes.com/recipe/264012/ajad-...
# 4646  https://www.allrecipes.com/recipe/240387/sweet...
#
#                                             recipe_name  \
# 0                         Roast duck with Marsala gravy
# 1                            Best-ever Brussels sprouts
# 2                         Beautiful courgette carbonara
# 3                            Roasted black bean burgers
# 4                            Chicken & tofu noodle soup
# ...                                                 ...
# 4642  Thai-Style Steamed Pumpkin Cake Recipe - Allre...
# 4643  Delicious Spicy Tomato Salad Recipe - Allrecip...
# 4644   Spicy Sriracha Meatballs Recipe - Allrecipes.com
# 4645  Ajad (Authentic Thai Cucumber Salad) Recipe - ...
# 4646  Sweet Thai-Style Chicken Bowl Recipe - Allreci...
#
#                                             ingredients  cuisines  \
# 0     ['1 x 1.6kg whole duck', '2 heaped teaspoons C...  American
# 1     ['800 g Brussels sprouts', '2 higher-welfare C...    French
# 2     ['6 medium green and yellow courgettes', '500 ...    Indian
# 3     ['1½ red onions', '200 g mixed mushrooms', '10...    French
# 4     ['2 shallots', '2 cloves of garlic', '2 cm pie...  Japanese
# ...                                                 ...       ...
# 4642  ["1 (2 pound) pumpkin - peeled, seeded, and gr...    French
# 4643  ["1 apple - peeled, cored and sliced","1 chile...    Indian
# 4644  ["1 egg","1 lime, zested","1 tablespoon creamy...   Chinese
# 4645  ["1 1/2 teaspoons salt","1/2 cup white vinegar...  Japanese
# 4646  ["1 (14 ounce) can coconut milk","1 1/2 cups j...  Japanese
#
#       cooking_time cooking_level  general_rank  like  user_rank  \
# 0              105          Easy             5     1          2
# 1              120          Hard             4    -1          4
# 2               15          Hard             4     1          5
# 3               60          Hard             3    -1          4
# 4              120          Easy             4    -1          4
# ...            ...           ...           ...   ...        ...
# 4642            90          Easy             5    -1          5
# 4643            45          Easy             5     1          2
# 4644            75        Medium             5     0          2
# 4645            45          Hard             3     0          4
# 4646            15          Hard             3    -1          3
#
#       general_rank_weighted  user_rank_weighted
# 0                  1.609438            0.693147
# 1                  1.386294            1.386294
# 2                  1.386294            1.609438
# 3                  1.098612            1.386294
# 4                  1.386294            1.386294
# ...                     ...                 ...
# 4642               1.609438            1.609438
# 4643               1.609438            0.693147
# 4644               1.609438            0.693147
# 4645               1.098612            1.386294
# 4646               1.098612            1.098612
#
# [4647 rows x 11 columns]
